# %%
# %%HTML
# <!-- Run this code block first -->
# <!-- !!DO NOT DELETE!! -->
# <link rel="stylesheet" type="text/css" href="Resources/Styles/styles.css">

# %% [markdown]
# <div class = "main-container">
#     <div class = "inner_container">
#         <img src="Resources/Images/Multiverse_Logo.png" class = 'image_style' />
#     </div>
# </div>

# %% [markdown]
# <div class = 'main-container'>
#     <div class = 'inner_container'>
#         <h1><mark class = "highlight_green">Aberfeldy Schools starter code</mark></h1>
#                 <p>A California-based Real Estate company wants to build a client-facing dashboard to show recent house prices and estimated rental income.<br><br><b>Information which you will require for this project, including stakeholders, deliverables and data dictionaries can be found in the project brief.</b></p>
#     </div>
# </div>

# %%
# import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data

aber_data = pd.read_csv('Resources/Data/college_data.csv')

display(aber_data.head())

# %%
# example of a function

def state_select(college):
    
    # filter DataFrame to show only records from that college
    
    output = aber_data[aber_data['College'] == state]
    
    # return output
    
    return output

# %%
state_select('Adrian College')

# %%
# enter code from here
